# %% [markdown]
# ### Starting with Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("employee_formated.xlsx")

# %%
print(df)

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.index

# %%
df.columns

# %%
df.describe()

# %%
df.T

# %%
df.sort_index(ascending=False)

# %%
df = pd.DataFrame({"A":[1,2,3],"B":[4,5,6]})
df.head()
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6]])
pd.DataFrame(arr)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.DataFrame(np.random.rand(4,8),columns=list('abcdefgh'))
df.rename(columns={"a":"Any thing"},inplace=True)
df
# Out:
#    Any thing         b         c         d         e         f         g  \
# 0   0.554527  0.707363  0.778352  0.922963  0.103555  0.491179  0.011360
# 1   0.374517  0.487647  0.226730  0.277191  0.806286  0.476892  0.036669
# 2   0.942683  0.027702  0.272844  0.822210  0.242851  0.659137  0.229971
# 3   0.035097  0.957998  0.731047  0.887827  0.721287  0.872550  0.311561
#
#           h
# 0  0.598013
# 1  0.439588
# 2  0.766636
# 3  0.074282

# %%
df.columns=df.columns.str.replace(' ','')
df
# Out:
#    Anything         b         c         d         e         f         g  \
# 0  0.554527  0.707363  0.778352  0.922963  0.103555  0.491179  0.011360
# 1  0.374517  0.487647  0.226730  0.277191  0.806286  0.476892  0.036669
# 2  0.942683  0.027702  0.272844  0.822210  0.242851  0.659137  0.229971
# 3  0.035097  0.957998  0.731047  0.887827  0.721287  0.872550  0.311561
#
#           h
# 0  0.598013
# 1  0.439588
# 2  0.766636
# 3  0.074282

# %%
df = df.add_prefix('something')
df
# Out:
#    somethingsomethingAnything_GG  somethingsomethingb_GG  \
# 0                       0.554527                0.707363
# 1                       0.374517                0.487647
# 2                       0.942683                0.027702
# 3                       0.035097                0.957998
#
#    somethingsomethingc_GG  somethingsomethingd_GG  somethingsomethinge_GG  \
# 0                0.778352                0.922963                0.103555
# 1                0.226730                0.277191                0.806286
# 2                0.272844                0.822210                0.242851
# 3                0.731047                0.887827                0.721287
#
#    somethingsomethingf_GG  somethingsomethingg_GG  somethingsomethingh_GG
# 0                0.491179                0.011360                0.598013
# 1                0.476892                0.036669                0.439588
# 2                0.659137                0.229971                0.766636
# ...

# %%
df = df.add_suffix('_GG')
df
# Out:
#    somethingAnything_GG  somethingb_GG  somethingc_GG  somethingd_GG  \
# 0              0.554527       0.707363       0.778352       0.922963
# 1              0.374517       0.487647       0.226730       0.277191
# 2              0.942683       0.027702       0.272844       0.822210
# 3              0.035097       0.957998       0.731047       0.887827
#
#    somethinge_GG  somethingf_GG  somethingg_GG  somethingh_GG
# 0       0.103555       0.491179       0.011360       0.598013
# 1       0.806286       0.476892       0.036669       0.439588
# 2       0.242851       0.659137       0.229971       0.766636
# 3       0.721287       0.872550       0.311561       0.074282

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.to_csv('tips.csv')

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.select_dtypes(include=['number'])
# Out:
#      Unnamed: 0  total_bill   tip  size
# 0             0       16.99  1.01     2
# 1             1       10.34  1.66     3
# 2             2       21.01  3.50     3
# 3             3       23.68  3.31     2
# 4             4       24.59  3.61     4
# ..          ...         ...   ...   ...
# 239         239       29.03  5.92     3
# 240         240       27.18  2.00     2
# 241         241       22.67  2.00     2
# 242         242       17.82  1.75     2
# 243         243       18.78  3.00     2
#
# [244 rows x 4 columns]

# %%
df.astype({'size':'int64'}).dtypes
# Out:
# Unnamed: 0      int64
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df = pd.read_clipboard()
df
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female
# 5       25.29  4.71    Male
# 6        8.77  2.00    Male

# %%
df.shape
# Out:
# (7, 3)

# %%
df_1 = df.sample(frac=0.5,random_state=1)
df_1.shape
# Out:
# (4, 3)

# %%
df_2 = df.drop(df_1.index)
df_2.shape
# Out:
# (3, 3)

# %%
df_3 = df_1.append(df_2)
df_3.shape
# Out:
# C:\Users\shuva\AppData\Local\Temp\ipykernel_8904\3067156347.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_3 = df_1.append(df_2)
# (7, 3)

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df.sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df[(df.smoker=='Yes') &
    (df.sex=='Female')]
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 67           67        3.07  1.00  Female    Yes   Sat  Dinner     1
# 72           72       26.86  3.14  Female    Yes   Sat  Dinner     2
# 73           73       25.28  5.00  Female    Yes   Sat  Dinner     2
# 92           92        5.75  1.00  Female    Yes   Fri  Dinner     2
# 93           93       16.32  4.30  Female    Yes   Fri  Dinner     2
# 100         100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101         101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102         102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103         103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 109         109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 164         164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168         168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169         169       10.63  2.00  Female    Yes   Sat  Dinner     2
# ...

# %%
df[(df.smoker=='Yes') &
   (df.day=='Sat') &
    (df.sex=='Female')]
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 67           67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 72           72       26.86  3.14  Female    Yes  Sat  Dinner     2
# 73           73       25.28  5.00  Female    Yes  Sat  Dinner     2
# 102         102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 103         103       22.42  3.48  Female    Yes  Sat  Dinner     2
# 109         109       14.31  4.00  Female    Yes  Sat  Dinner     2
# 168         168       10.59  1.61  Female    Yes  Sat  Dinner     2
# 169         169       10.63  2.00  Female    Yes  Sat  Dinner     2
# 209         209       12.76  2.23  Female    Yes  Sat  Dinner     2
# 213         213       13.27  2.50  Female    Yes  Sat  Dinner     2
# 214         214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 215         215       12.90  1.10  Female    Yes  Sat  Dinner     2
# 219         219       30.14  3.09  Female    Yes  Sat  Dinner     4
# ...

# %%
df[df.total_bill > 30]
# Out:
#      Unnamed: 0  total_bill    tip     sex smoker   day    time  size
# 11           11       35.26   5.00  Female     No   Sun  Dinner     4
# 23           23       39.42   7.58    Male     No   Sat  Dinner     4
# 39           39       31.27   5.00    Male     No   Sat  Dinner     3
# 44           44       30.40   5.60    Male     No   Sun  Dinner     4
# 47           47       32.40   6.00    Male     No   Sun  Dinner     4
# 52           52       34.81   5.20  Female     No   Sun  Dinner     4
# 56           56       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59           59       48.27   6.73    Male     No   Sat  Dinner     4
# 83           83       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85           85       34.83   5.17  Female     No  Thur   Lunch     4
# 95           95       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102         102       44.30   2.50  Female    Yes   Sat  Dinner     3
# ...

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64
